# %%
import matplotlib.pyplot as plt

_data =[["08/2017", "126393.38194313418"], ["08/2016", "103201.08623144105"], ["02/2017", "79977.49780928274"], ["11/2015", "552664.1394938199"], ["06/2017", "113876.9744479187"], ["05/2017", "76781.97880585"], ["09/2017", "155498.0710504653"], ["11/2017", "164991.69973455978"], ["09/2018", "380391.05840727483"], ["09/2016", "108371.14506651415"], ["08/2015", "364774.4365979381"], ["10/2015", "1064341.6212"], ["12/2016", "69184.02698567968"], ["01/2019", "297607.5745047373"], ["12/2018", "371121.50413734367"], ["10/2018", "242422.9136741674"], ["08/2018", "371054.7681104046"], ["01/2017", "58527.96717527603"], ["11/2018", "313926.43661742256"], ["10/2017", "159537.97692200154"], ["04/2018", "494338.83781044686"], ["01/2016", "358606.7810440953"], ["04/2016", "423392.48398576514"], ["07/2016", "178556.58677363582"], ["07/2018", "318457.6656414988"], ["03/2016", "233806.23642072213"], ["11/2016", "84808.37901889467"], ["12/2017", "211222.11535451622"], ["01/2018", "240366.16341630253"], ["03/2018", "344916.6728983044"], ["07/2017", "121299.32492440357"], ["04/2017", "82945.25166887816"], ["09/2015", "607479.3711739635"], ["10/2016", "125195.6470383587"], ["02/2018", "299701.0380516722"], ["02/2016", "304524.2311879603"], ["05/2016", "722742.1068875446"], ["06/2018", "390420.2776759686"], ["06/2016", "347263.67920171865"], ["03/2017", "70452.7594065135"], ["12/2015", "445948.3533201189"], ["05/2018", "361403.6319048684"]]

# %%
sort_et_data = sorted(et_data, key=lambda x: tuple(map(int, x[0].split('/')[::-1])) if isinstance(x[0], str) else x[0])

Date1 = [d[0] for d in sorting_avg_data]
Value = [float(d[1]) for d in sorting_avg_data]

plt.plot(Date1,Value)

plt.xticks(Date1[::12], [d[-4:] for d in Date1[::12]])

plt.xlabel('Time')
plt.ylabel('Gas used')
plt.title('Graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 sort_et_data = sorted(et_data, key=lambda x: tuple(map(int, x[0].split('/')[::-1])) if isinstance(x[0], str) else x[0])
#       3 Date1 = [d[0] for d in sorting_avg_data]
#       4 Value = [float(d[1]) for d in sorting_avg_data]
#
# NameError: name 'et_data' is not defined
